# %% [markdown]
# # <center> 3.Praktiskā nodarbība <br></center>
# # <center> 2.individuālais uzdevums - "Bezier līknes izveide"
#
#
# ---

# %% [markdown]
# #### Nodarbībā tiks aplūkots:
# - Bézier (Bezjē ) līknes matemātiskais pieraksts
# - Brenšteina polinoms
# - Bézier (Bezjē ) līknes attēlošanas piemērs

# %% [markdown]
# Tiek uzdoti vadošie kontrolpunkti
# <b>𝑃0,𝑃1,𝑃2,…,𝑃𝑛</b>
#
# kas dotu sākotnējo tuvinājumu nākošās līknes izskatam.
#
# Šos punktus savā starpā saista matemātiskā sakarība ar
# Bernšteina polinomu palīdzību. Polinomu pakāpe: 𝑛−1

# %% [markdown]
# <br>
# <br>
# <br>
# <b>Bezjē līknes katru punktu rēķina izmantojot parametru t:</b>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <b>Bernšteina polinoms:</b>
# $$
# \begin{array}{c}
# B_{i,n}(t)
# \end{array}
# $$
# <br>
# <br>
# <b>Lai noteikt Bernšteina polinomu izmanto šādu formulu:</b>
#
# ![image.png](attachment:image.png)
#
# t - parametrs, kas nosaka punkta atrašanās vietu uz līknes <br>
# i - šī brīža skaitītājs <br>
# N - kontrolpunktu skaits<br>
# n - polinoma pakāpe<br>
# n = N-1
#
# <br>
# <br>
# $$
# \begin{array}{c}
# B_{0,1}(t) = (1-t)\cr
# B_{1,1}(t) = t\cr
# \end{array}
# $$
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ---
# #### Pirmās pakāpes Bezjē līkne:
# $$
# \begin{array}{c}
# B_{0,1}(t) = 1 * (1-t)\cr
# B_{1,1}(t) = 1* t\cr
# \end{array}
# $$

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/0/00/B%C3%A9zier_1_big.gif" width="300" align="center">

# %% [markdown]
# ---
# #### Otrās pakāpes Bezjē līkne:
#
# $$
# \begin{array}{c}
# B_{0,2}(t) = (1-t)^2\cr
# B_{1,2}(t) = 2t(1-t)\cr
# B_{2,2}(t) = t^2\cr
# \end{array}
# $$

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/3/3d/B%C3%A9zier_2_big.gif" width="300" align="center">

# %% [markdown]
# ---
# #### Trešās pakāpes Bezjē līkne:
#
# $$
# \begin{array}{c}
# B_{0,3}(t) = (1-t)^3\cr
# B_{1,3}(t) = 3t(1-t)^2\cr
# B_{2,3}(t) = 3t^2(1-t)\cr
# B_{3,3}(t) = t^3\cr
# \end{array}
# $$

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/d/db/B%C3%A9zier_3_big.gif" width="300" align="center">

# %% [markdown]
# ### Paskāla trīsstūris:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
#
# #### Ja mums doti trīs kontrolpunkti P0, P1, P2, tad mums nepieciešams:
#
# > - 1) Noteikt sākumpunktu: tas ir pirmais kontrolpunkts P0.
#
# > - 2) Noteikt soli t, ar kuru skaitīs punktus
#
# > - 3) Sakot ar t=0 izmantot t kā iteratīvo soli, kamēr t = 1
#
# > - 4) Noteikt Bernšteina polinomus solī t
#
# > - 5) Noteikt punkta koordinātes solī t
#
# > - 6) Attēlot uz ekrāna punktu (x, y)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np               
import matplotlib.pyplot as plt  

img = np.ones((600,600,3))

#Man ir 3 kontrolpunkti 
                #P0    P1      P2     
def DrawBezier(x0,y0, x1,y1, x2,y2):
    
    x = x0 # sākumpunkta definēšana pēc x ass
    y = y0 # sākumpunkta definēšana pēc y ass
    t = 0 # parametrs t, kas pieder intervālam no 0 līdz 1
    ts = 0.001 # solis, ar kuru mainās parametrs t. Jo mazāks ir solis ts,
    #jo vairāk punktu uz līknes uzzīmēs algoritms. 

    while t <= 1.0:  # kamēr nav sasniegts interavala gala punkts
        
        B0 = 1*(1-t) * (1-t) #rēķinam Beršteina 0.polinomu
        B1 = 2* (1-t) * t #rēķinam Beršteina 1.polinomu
        B2 = 1* t * t # #rēķinam Beršteina 2.polinomu
       
        x = int(x0*B0 + x1*B1 + x2*B2) #rēķinam līknes pikseļa koordinātes pēc x ass
        y = int(y0*B0 + y1*B1 + y2*B2) #rēķinam līknes pikseļa koordinātes pēc y ass
        
        img[y,x] = (1,0,0) #zīmējam tekošo pikseli sarkanajā krāsā
        
        t=t+ts #palielinam t vērtību
        
    return
             # P0         P1          P2          
DrawBezier(500, 100,     10, 10,    500, 550) #zīmējam līkni
    
# %matplotlib notebook
plt.figure(figsize=(10,8), dpi = 100, facecolor='w')
plt.imshow(img)
plt.show()
# Out:
# <div id='988e94d9-e69e-49b0-b696-2842bfd666d8'></div>

# %% [markdown]
# ---
#
# ## <center> 2.Individuālais uzdevums

# %% [markdown]
# Izveidot ar vienu vai vairākām Bezier līknēm vienu ciparu (<i> balstoties uz variantu</i> ). Iespējamais kontrolpunktu skaits - no 4 līdz 8!
#
# Variantu saraksts pieejams ORTUS vidē pie 4.praktiskās nodarbības! Varianta numurs atbilst studentu apliecības numura pēdējiem 3 cipariem. Piemēram,  ja jūsu pēdējie 3 studentu apliecības numura cipari ir 154, tad jāizvēlas variants 154 variantu sarakstā. Pirmajā kollonā redzams cipars, kuru nepieciešams uzzīmēt ar Bezier līknēm un otrajā kollonā atrodams no cik kontrolpunktiem jāsastāv zīmētajām Bezier līknēm.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Papildus kontrolpunktu aprēķinu algoritmā iespējams izveidot ar Bernšteina polinoma palīdzību.
#
# Iespējamās variācijas:
# - cipars (3, 6, 8, 9 – tie kuru izveidei ir iespējams līknes izmantot efektīvi),
# - punktu skaits (4-8 kontrolpunkti).

# %% [markdown]
# ### Paskāla trīsstūris:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Uzdevuma izpildes piemērs:
#
# ![image.png](attachment:image.png)
