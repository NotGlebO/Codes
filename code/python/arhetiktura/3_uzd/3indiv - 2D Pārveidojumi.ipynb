# %% [markdown]
# # <center> 4.Praktiskā nodarbība/ 3.individuālais uzdevums <br> 2D pārveidojumi

# %% [markdown]
# Nodarbībā tiks aplūkots:
# - 2D objektu pārveidojumi
#     - Pārvietošana
#     - Mērogošana
#     - Pagriešana

# %% [markdown]
# #### Pārvietošana:
#
# Vispārīgā gadījumā, ja mums ir
# kāds punkts (𝑥,𝑦), pārveidot
# (<b>pārvietot</b>) to var ja pieskaitīt
# punkta koordinātēm nobīdīšanas
# koeficientus.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Pārvietošanas blokshēma:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Mērogošana:
# Vispārīgā gadījumā, ja mums ir
# kāds punkts (𝑥,𝑦), pārveidot
# (<b>mērogot</b>) to var ja pareizināt
# punkta koordinātes ar
# mērogošanas koeficentu.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### <center> Mērogošanas blokshēma: </center>
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Pagriešana:
#
# Vispārīgā gadījumā, ja mums ir kāds
# punkts (𝑥,𝑦), pārveidot (<b>pagriezt</b>)
# to var ja pareizināt punkta
# koordinātes ar sinusiem un
# kosinusiem(!!!)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# #### <center> Pagriešanas blokshēma: </center>
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# #### 2D objekta pārveidošanas piemērs:
#
# ![image.png](attachment:image.png)

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

img = np.ones((1000,1000,3))

point1 = (300,100)
point2 = (100,100)
point3 = (100,300)
point4 = (300,300)

    #Pārvietošana
def MoveObject(x1, y1, x2, y2, x3, y3, x4, y4):
   
    move_x = int(input("Pārvietojums pa X asi: "))
    move_y = int(input("Pārvietojums pa Y asi: "))
    
    x1 = x1 + move_x
    y1 = y1 + move_y
    x2 = x2 + move_x
    y2 = y2 + move_y
    x3 = x3 + move_x
    y3 = y3 + move_y
    x4 = x4 + move_x
    y4 = y4 + move_y
    
    x5 = [x1,x2,x3,x4,x1]
    y5 = [y1,y2,y3,y4,y1]
    plt.plot(x5,y5)
    
    #Mērogošana
#def ScaleObject(x1, y1, x2, y2, x3, y3, x4, y4):
    
    #Rotēšana
#def RotateObject(x1, y1, x2, y2, x3, y3, x4, y4):
    #!Neaizmirst par prveidosanu no deg uz radians!!

    
# %matplotlib notebook
plt.figure(figsize=(10,8), dpi = 100, facecolor='w')
plt.imshow(img)

MoveObject(point1[0],point1[1],point2[0],point2[1],point3[0],point3[1],point4[0],point4[1])

plt.show()
# Out:
# <div id='f195b264-fbda-45a1-b36f-d4897c352ac8'></div>

# %% [markdown]
# # <center> 3.Individuālais uzdevums

# %% [markdown]
# Individuālā uzdevuma izpildes laikā jārealizē pārvietošana, mērogošana un rotācija kādam 2D objektam, balstoties uz variantu, kuru var atrast ORTUS vidē. Variants atkarīgs no studentu apliecības numura pēdējiem 3 cipariem.
#
# Uzdevuma variācijas:
# - pārvietot objektu par N-koordināšu skaitu, pa x un y asīm,
# - mērogošana – samazināt vai palielināt objektu N-reizes pa x un y asīm,
# - rotēt objektu N-grādos.

# %% [markdown]
# ### <center> 3.Individuālā uzdevuma izpildes piemērs
# ![image.png](attachment:image.png)
