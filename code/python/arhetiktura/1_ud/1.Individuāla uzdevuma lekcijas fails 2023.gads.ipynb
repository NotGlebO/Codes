# %% [markdown]
# # <center>2.Nodarība / 1.Individuālais uzdevums - Taisnes izveides algoritms <center>
# ---
# ## Struktūra:
# ### &emsp; &emsp;&emsp; &emsp; 1) Papildus Python bibliotēku importēšana
# ### &emsp; &emsp;&emsp; &emsp; 2) Horizontālas līnijas izveide
# ### &emsp; &emsp;&emsp; &emsp; 3) Pirmā individuālā uzdevuma izklāsts
# ---

# %% [markdown]
# ## Papildus Python bibliotēku importēšana

# %% [markdown]
# Lai pievienotu jaunas bibliotēkas tās sākumā jāuzinstalē atbilstošajā darbības vidē.
#
# Darbojoties ar Anaconda un Jupyter Notebook, jaunas bibliotēkas un modeļus iespējams instalēt Anaconda Prompt vai Anaconda Navigator.
#
# Tālāk, veidojot programmas skriptu, attiecīgā bibliotēka vai modelis tiek importēs ar:
#
# ### <center> **import** [modeļa/pakotnes nosaukums] <center>

# %% [markdown]
# Lai instalētu jaunas bibliotēkas, nepieciešams Anaconda Prompt ievadīt sekojošas komandas:
#
# #### <center>conda install -c conda-forge matplotlib <center>
#
# #### <center>conda install -c anaconda numpy <center>
#
# #### <center>conda install -c anaconda pillow<center>
#
# #### <center>conda install -c conda-forge opencv<center>
# <br><br>
# Anaconda vidē jau automātiski ir iekļautas bibliotēkas numpy un matplotlib, pillow (PIL), tādēļ tās iespējams izsaukt ar sekojošo skriptu:

# %%
                                            #Papildus Python bibliotēku importēšana

#matplotlib grafu vizualai attelosanai Jupyter notebook
import matplotlib.pyplot as plt

#Numpy matemātiskajiem aprēķiniem un darbībām ar matricām
import numpy as np

#Pillow importēšana attēlu apstrādei
import PIL

#Papildus bibliotēkas OpenCV importēšana attēlu apstrādei
import cv2

# %% [markdown]
# ## Brezenhema algoritms: Algoritmizācija
#
# ### Kāpēc tieši Brezenhema algoritms taisnes izveidošanai?
#
# Bresenham līnijas algoritms ir līnijas zīmēšanas algoritms, kas nosaka n-dimensiju rastra punktus, kas jāizvēlas, lai veidotu tuvu taisnei starp diviem punktiem. Tas ir viens no agrākajiem algoritmiem, kas izstrādāts datorgrafikas jomā.
#
# Šis algoritms tiek izmantots skenēšanai, pārveidojot līniju. Tā tiek uzskatīta par efektīvu metodi, jo tā ietver tikai vesela skaitļa saskaitīšanu, atņemšanu un reizināšanas operācijas. Šīs darbības var veikt ļoti ātri, lai ātri izveidotu līnijas.
#
#
# ### Brezenhema algoritma priekšrocības:
# * viegli saprotams;
# * salīdzinoši viegli realizēt;
# * efektīva un ātra darbība;
# * punktu precizitāte.
#
# ### Pamatprincips:
#
#     1. sākotnēji tiek definētas sākuma vērtības;
#     2. pārbauda, vai vērtības iekļaujas definētajās robežās;
#     3. pārbauda risināmā parametra vērtību;
#        3.1. ja p ir mazāks par nulli -> x koordinātes aprēķins;
#        3.2. ja p ir lielāks par nulli -> y koordinātes aprēķins;
#     4. taisnes zīmēšana ar DrawLine;
#     5. taisnes attēlošana ar plt.imshow(img) un izvade ar plt.show().

# %% [markdown]
# ### Pilna formāta algoritma izpildes blokshēma:
#
# ![Bresenhems.jpg](attachment:Bresenhems.jpg)

# %% [markdown]
# ### Saīsināta formāta algoritma izpildes blokshēma:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Horizontālas līnijas izveide

# %% [markdown]
# Brezenhema algoritma būtība:
# Ir doti sākumpunkts (𝑥0, 𝑦0) un galapunkts (𝑥_𝑔, 𝑦_𝑔).
# Algoritms rēķina sākotnējo risinājušo parametru p0:
#
#                                                𝑝0=2∆𝑦−∆𝑥
#
# Tā kā mums nav iepriekšēja punkta, šis ir vienīgais parameters, kas rēķinās neatkarīgi.
#
#
#
#
# Ja 𝑝0<0 tad 𝑑1<𝑑2, tas nozīmē, ka nākošais pikselis būs
# (𝑥_𝑛+1, 𝑦_𝑛)
# 𝑝1=𝑝0+2∆𝑦
#
# Ja 𝑝0>0 tad 𝑑1>𝑑2, tas nozīmē, ka nākošais pikselis būs
# (𝑥_𝑛+1, 𝑦_𝑛+1)
# 𝑝1=𝑝0+2∆𝑦−2∆𝑥!

# %% [markdown]
# ### Vertikālas līnijas izveide

# %% [markdown]
# Lai izveidotu vertikālu līniju, nepieciešams visos nosacījumos un formulās samainīt x vērtības ar y vērtībām.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  ## <center> Horizontālas līnijas izveide <center>

# %%
                                   #### Importē nepieciešamās bibliotēkas ###
import numpy as np                 #masīvu izveide un informācijas apstrāde
import matplotlib.pyplot as plt    #lai izvadītu/attēlotu attēla matricu un līnijas


                        #### Izveido tukšu attēla matricu, uz kuras tālāk zīmēt līnijas ####
#Matrica sākas ar augstuma vērtību, kas atbilstoši ir y, sekojot tam ar platuma vērtību kas ir x
#Ja vēlas paplašināt zīmēšanas reģionu - samaina augstumu(height) un platumu(width), kas šajā piemērā ir 600,600
img=np.ones((600,600,3)) 

                            #### Līnijas zīmēšanas algoritma definēšana ####
#Tiek definēta funkcija 'DrawLine', ar kuras palīdzību tiek realizēts līnijas aprēķināšanas algoritms
#x1,y1 - sākuma koordināte
#x2,y2 - beigu koordināte
def DrawLine(x1,y1,x2,y2):
    #Ja aprēķina rezultāts ir negatīva vērtība, tad tā tiek pārveidota par pozitīvu
    dx = abs(x2-x1) #dx - delta x, jeb starpība starp pēdējo x vērtību un sākuma x vērtību
    dy = abs(y2-y1) #dy - delta y, jeb starpība starp pēdējo y vērtību un sākuma y vērtību  

    #Ja sākuma x vērtība(x1) ir mazāka par beigu x vērtību(x2), tad x sākuma vērtība ir 1
    if x1<x2:
        xs=1 
    #citādāk x sākuma vērtība ir -1
    else:
        xs=-1   
        
    #Ja sākuma y vērtība(y1) ir mazāka par beigu y vērtību(y2), tad y sākuma vērtība ir 1
    if y1<y2:
        ys=1
    #citādāk y sākuma vērtība ir -1
    else:
        ys=-1
     
    
    #pārdefinē x1 un y1 par mainīgajiem x un y, lai tālāk to izmantotu matemātisko aprēķinu ciklā
    x=x1
    y=y1  
    
    #tiek aprēķināts risinošais parametrs p, pēc kura tiek noteiktas nākošā pikseļa koordinātes
    p=2*dy-dx   
    
                            #### Horizontālas līnijas aprēķins ####

    #Ja delta x ir lielāks par delta y, tad kamēr x ir mazāks par definēto beigu x koordināti
    if dx>dy:
        while x!=x2:
            #tad mainīgais x ir tekošā x vērtība + x sākuma vērtība
            x=x+xs
            #ja risinošais parametrs ir lielāks par 0
            if p > 0:
                #tad y vērtība pielīdzināma tekošajai y vērtībai + y sākuma vērtībai
                y=y+ys
                #parametra vērtība tiek definēta kā tekošā parametra vērtība +2 * delta y - 2* delta x
                p=p+2*dy-2*dx
            #citādāk parametra vērtība tiek definēta kā tekošā parametra vērtība + 2* delta y
            else:
                p=p+2*dy  

            #tiek attēlota taisne, 0 = melna krāsa
            img[y,x]= 0
     
    #ar 'return' atgriežas uz procesa sākumu, atkarto kamēr līnija nonāk līdz beigu koordinātēm
    return
                                      
                                                #### Izvade ####
#Ja vēlas līniju attēlot jaunā logā, ja vēlas atslēgt - jārestartē kernel ar izvadēm
#%matplotlib qt

#Zīmēt līniju (x1, y1, x2, y2)
#        sākuma   beigu
DrawLine(100,500,500,500)    #horizontāla līnija

#Gan zīmēšanas paneļa, gan taisņu izvade
plt.imshow(img)
#Izvade Notebook
plt.show()

# %% [markdown]
# ## 1.Individuālā uzdevuma - "Taisnes izveide" apraksts
#
# Balstoties uz praktiskās nodarbības laikā aplūkoto Brezenhema algoritma realizāciju, izveidot no vairākām taisnēm savus pēdējos 3 studenta apliecības numura skaitļus (piemēram, ja Jūsu studentu apliecības numurs ir 200RDB153, tad Jums ir jāizveido skaitļi 153)
# <center>__________________________________<center>
# <center><b>ORTUS vidē nepieciešams iesniegt: </b><center>
# <center>Jupyter Notebook failu ("*.ipynb" formātā), izpildītu pēc noformējuma šablona, ar individuālā uzdevuma izpildi <center><br>
#     <center><b>Failā jāiekļauj:</b> <center>
# <center>Uzdevuma nostādne, <center>
# <center>Individuālā uzdevuma izpildes kods, <center>
# <center>Ieteicami arī ekrānuzņēmumi ar koda darbību. <center>
# <center>Faila noformējuma šablons pieejams kursa praktisko nodarbību sadaļā <center>
# <center>__________________________________<center>

# %% [markdown]
# ## Individuālā varianta viena skaitļa piemērs:

# %% [markdown]
# ![image.png](attachment:image.png)
